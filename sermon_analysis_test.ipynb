# %%
from docx import Document
import os
all_book = ["創", "出", "利", "民", "申", "書", "士", "得", "撒上", "撒下", "王上", "王下", "代上", "代下", "拉", "尼", "斯", "伯", "詩", "箴", "傳", "歌", "賽", "耶", "哀", "結", "但", "何", "珥", "摩", "俄", "拿", "彌", "鴻", "哈", "番", "該", "瑪", "亞", "太", "可", "路", "約", "徒", "羅", "林前", "林後", "加", "弗", "腓", "西", "帖前", "帖後", "提前", "提後", "多", "門", "來", "雅", "彼前", "彼後", "約壹", "約貳", "約參", "猶", "啟"]
number = ["1", "2", "3", "4", "5", "6", "7", "8", "9", "0"]
books = "創|出|利|民|申|書|士|得|撒上|撒下|王上|王下|代上|代下|拉|尼|斯|伯|詩|箴|傳|歌|賽|耶|哀|結|但|何|珥|摩|俄|拿|彌|鴻|哈|番|該|瑪|亞|太|可|路|約|徒|羅|林前|林後|加|弗|腓|西|帖前|帖後|提前|提後|多|門|來|雅|彼前|彼後|約壹|約貳|約參|猶|啟"

# %%
# wordfile_path = r"D:\kou ray\python\church\20251019新竹主日週報.docx"
wordfile_path = r"/Volumes/Rye/code/FaitSlide/20251019新竹主日週報.docx"
sermon = []
doc = Document(wordfile_path)
text_box = []
for t_idx, table in enumerate(doc.tables):
    # print(f"=== 表格 {t_idx+1} ===")
    for r_idx, row in enumerate(table.rows):
        # 取每個儲存格文字，去掉前後空白
        
        # print(row_texts)
        tatil = row.cells[0].text.strip()
        # 只印出有內容的列
        if tatil == "讀經":
            row_texts = [cell.text.strip() for cell in row.cells]
            ReadTheBible = row_texts[1].split("\n")
        elif tatil == "證道": 
            bold_texts  = ""
            for cell in row.cells:
                for para in cell.paragraphs:
                    for run in para.runs:
                        text = run.text.strip()
                        if run.bold and text:
                            # print(text)
                            text_box.append(text)
                            if bold_texts == "證道":
                                bold_texts = text
                            else:
                                if text in ["錢致榮", "牧師", "傳道", "吳佩倫"]:
                                    if bold_texts != "":
                                        # print("遇到講員名稱，結束證道內容擷取", bold_texts)
                                        sermon.append(bold_texts)
                                    bold_texts = ""
                                    continue
                                for symbol in ["、", ".", ")"]:
                                    if symbol in bold_texts:
                                        # print("遇到分隔符號，結束證道內容擷取", symbol, bold_texts)
                                        if bold_texts.split(symbol)[1] == "":
                                            continue
                                        first_part = bold_texts.split(symbol)[0]
                                        second_part = first_part[-1][-1] + symbol + bold_texts.split(symbol)[1]
                                        first_part = first_part[:-1]
                                        if first_part:
                                            sermon.append(first_part)
                                        if second_part: 
                                            sermon.append(second_part)
                                        bold_texts = text
                                        break
                                else:
                                    for book in all_book:
                                        # if book in bold_texts:
                                            # print(bold_texts.index(book)+len(book), len(bold_texts))
                                        if book in bold_texts and (bold_texts.index(book)+len(book) == len(bold_texts) or bold_texts[bold_texts.index(book)+1] in ["1", "2", "3", "4", "5", "6", "7", "8", "9", "0"]):
                                            first_part = bold_texts.split(book)[0]
                                            bold_texts = bold_texts.replace(first_part, "")
                                            # print("遇到書卷，結束證道內容擷取", book, first_part, bold_texts)
                                            if first_part:
                                                sermon.append(first_part)
                                            if bold_texts:
                                                sermon.append(bold_texts)
                                            bold_texts = text
                                            break
                                    else:
                                        n = ""
                                        min_num_index = len(bold_texts)
                                        for num in number:
                                            if num in bold_texts:
                                                idx = bold_texts.index(num)
                                                if idx < min_num_index:
                                                    min_num_index = idx
                                                    n = num
                                        # print("最小數字索引", min_num_index, n)
                                        if n and n in bold_texts:
                                            # print(bold_texts.split(n))
                                            first_part = bold_texts.split(n)[0]
                                            bold_texts = bold_texts.replace(first_part, "").replace(" ","")
                                            # print("遇到數字，結束證道內容擷取", n, first_part)
                                            if first_part:
                                                if first_part in all_book:
                                                    sermon.append(first_part)
                                                else:
                                                    sermon[-1] += first_part
                                            bold_texts += text

                                        else:
                                            # print(bold_texts, text)
                                            bold_texts += text
                                            continue
sermon.append(bold_texts)
# print(sermon)
print(text_box)
# Out:
# ['證道', '與主相連！', '吳佩倫', '傳道', '一、領受多結果子的生命：', '1.', '悔', '改的果子', '：', '太', '3:8-10', '2.', '與', '神和好的果子：', '來', '12:11', '3.', '活像耶穌生命的果子：加', '5:22-23', '，弗', '5:9', '4.', '善事的果子：西', '1:10', '，弗', '2:10', '5.', '福音的果子：羅', '1:13', '，約', '15:16', '二、真實經歷耶穌的生命：', '1.', '禱告蒙應允：約', '15:7,16', '2.', '滿溢的喜樂：約', '15:11', '，詩', '16:9,11', '，來', '12:2', '3.', '成為主朋友：約', '15:14-15', '，創', '18:17', '三、追求與耶穌相連！', '1.', '真理潔淨我心：約', '15:1-3', '，詩', '19:7-9', '2.', '遵行神的命令～彼此相愛！', '約', '15:9-10,12-13,17', '1)', '捨命之愛：約', '15:12-13,13:1-5', '，約壹', '3:16-18', '2)', '支取愛的智慧：腓', '1:9-10', '3)', '領受愛的能力：弗', '3:14-20']

# %%
import re
text = " ".join(text_box)
for word in ["證道", "傳道", "牧師", "吳佩倫", "錢致榮"]:
    text = text.replace(word, "")
parts = re.split(r'(?=[一二三四五六七八九十]+、|\d+\.|\d+\))', text)
sermon = []
for p in parts:
    # print(p)
    title = p
    del_matches = re.findall(rf"(?<![\u4e00-\u9fff])(?:{books})+\s\d+:(?:\d+(?:-\d+)?)+(?:,\s\d+(?::\d+)*(?:-\d+)?)*", p)
    matches = re.findall(rf"(?<![\u4e00-\u9fff])(?:{books})+(?![\u4e00-\u9fff])|\d+:(?:\d+(?:-\d+)?)+(?:,\s\d+(?::\d+)*(?:-\d+)?)*", p)
    cleaned_matches = [m.replace(" ", "") for m in matches]
    if del_matches:
        title = title.split(del_matches[0])[0].replace(" ", "")

    sermon.append(title.strip())
    sermon.extend(cleaned_matches)
print(sermon)
# Out:
# ['與主相連！', '一、領受多結果子的生命：', '1.悔改的果子：', '太', '3:8-10', '2.與神和好的果子：', '來', '12:11', '3.活像耶穌生命的果子：', '加', '5:22-23', '弗', '5:9', '4.善事的果子：', '西', '1:10', '弗', '2:10', '5.福音的果子：', '羅', '1:13', '約', '15:16', '二、真實經歷耶穌的生命：', '1.禱告蒙應允：', '約', '15:7', '2.滿溢的喜樂：', '約', '15:11', '詩', '16:9', '來', '12:2', '3.成為主朋友：', '約', '15:14-15', '創', '18:17', '三、追求與耶穌相連！', '1.真理潔淨我心：', '約', '15:1-3', '詩', '19:7-9', '2.遵行神的命令～彼此相愛！', '約', '15:9-10', '1)捨命之愛：', '約', '15:12-13', '13:1-5', '約壹', '3:16-18', '2)支取愛的智慧：', '腓', '1:9-10', '3)領受愛的能力：', '弗', '3:14-20']

# %%
# text = "約壹 1:3, 5-6, 8-10, 雅 2:3, 4, 箴 3:5-6, 5-7, 羅 4:5, 5:5"
text = "3. 活像耶穌生命的果子：耶 5:22-23 ，弗 5:9 "
title = text
title2 = text
del_matches = re.findall(rf"(?<![\u4e00-\u9fff])(?:{books})+\s\d+:(?:\d+(?:-\d+)?)+(?:,\s\d+(?::\d+)*(?:-\d+)?)*", text)
matches = re.findall(rf"(?<![\u4e00-\u9fff])(?:{books})+(?![\u4e00-\u9fff])|\d+:(?:\d+(?:-\d+)?)+(?:,\s\d+(?::\d+)*(?:-\d+)?)*", text)
# matches = re.findall(rf"(?<![\u4e00-\u9fff])(?:{books})(?![\u4e00-\u9fff])|\d+[:：](?:\d+(?:-\d+)?)+(?:,\s*\d+(?::\d+)*(?:-\d+)?)*",text)

cleaned_matches = [m.strip().replace(" ", "") for m in matches]

title = title.split(del_matches[0])[0]

print(title)
print(title2)
print(cleaned_matches)
# Out:
# 3. 活像耶穌生命的果子：
# 3. 活像耶穌生命的果子：耶 5:22-23 ，弗 5:9
# ['耶', '5:22-23', '弗', '5:9']

# %%
re.split(rf"(?=(?<![\u4e00-\u9fff])(?:{books})+(?![\u4e00-\u9fff])|\d+:(?:\d+(?:-\d+)?)+(?:,\s\d+(?::\d+)*(?:-\d+)?)*)", text)
# Out:
# ['3. 活像耶穌生命的果子：', '耶 ', '5:22-23 ，', '弗 ', '5:9 ']

# %%
print("3. 活像耶穌生命的果子：耶 5:22-23 ，弗 5:9".split('耶 5:22-23')[0])
# Out:
# 3. 活像耶穌生命的果子：

# %% [markdown]
# ['與主相連！', '一、領受多結果子的生命：', '1.悔改的果子：', '太', '3:8-10', '2.與神和好的果子：', '來', '12:11', '3.活像耶穌生命的果子：', '加', '5:22-23', '，弗', '5:9', '4.善事的果子：西', '1:10', '，弗', '2:10', '5.福音的果子：', '羅', '1:13', '，約', '15:16', '二、真實經歷耶穌的生命：', '1.禱告蒙應允：', '約', '15:7,16', '2.', '滿溢的喜樂：', '約', '15:11', '，詩', '16:9,11', '，來', '12:2', '3.成為主朋友：', '約', '15:14-15', '，創', '18:17', '三、追求與耶穌相連！', '1.真理潔淨我心：', '約', '15:1-3', '，詩', '19:7-9', '2.遵行神的命令～彼此相愛！', '約', '15:9-10,12-13,17', '1)', '捨命之愛：', '約', '15:12-13,13:1-5', '，約壹', '3:16-18', '2)', '支取愛的智慧：', '腓', '1:9-10', '3)', '領受愛的能力：', '弗', '3:14-20']
